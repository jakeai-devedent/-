# %% [markdown]
# <a href="https://colab.research.google.com/github/jakeai-devedent/-/blob/main/python_0306_genius.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#출렺
print ("Hello")
# Out:
# Hello

# %%
a=12
b=2.5
print(a+b)
# Out:
# 14.5

# %%
print ("뺄샘:",a-b)
print ("덧샘:",a+b)
print ("곱샘:",a*b)
print ("나눗샘:",a/b)
# Out:
# 뺄샘: 9.5
# 덧샘: 14.5
# 곱샘: 30.0
# 나눗샘: 4.8

# %%
num1=92
num2=88
num3=79
avg=(num1+num2+num3)/3
print ("평균:",avg)
# Out:
# 평균: 86.33333333333333
